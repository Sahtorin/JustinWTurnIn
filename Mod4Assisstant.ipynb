# %%
#11.1 couldnt connect python file to jupyter so I am giving the code I would use
def hours():
    print('Open 9-5 daily')
    
import zoo
zoo.hours()

# %%
#11.2 couldnt connect python file to jupyter so I am giving the code I would use
import zoo as menagerie
menagerie.hours()
