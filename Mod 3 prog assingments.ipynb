# %%
#7.4
things = ["mozzerella", "cinderella", "salmonella"]

# %%
#7.5
things = ["mozzerella", "cinderella", "salmonella"]
things = ["mozzerella", "cinderella", "salmonella"]
things[1] = things[1].capitalize()
print(things)

# %%
#7.6
things = ["mozzerella", "cinderella", "salmonella"]
things[0] = things[0].upper()
print(things)

# %%
#7.7
things = ["mozzerella", "cinderella", "salmonella"]
things[2] = things[2].pop()
print(things)

# %%
#9.1
def good():
    return ["Harry", "Ron", "Hermione"]

# %%
#9.2
def get_odds():
    for number in range(10):
        if number % 2 != 0:
            yield number

count = 0
for odd in get_odds():
    count += 1
    if count == 3:
        print(odd)
        break
