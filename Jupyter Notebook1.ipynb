# %%
seconds_per_minute = 60
minutes_per_hour = 60
seconds_per_hour = seconds_per_minute * minutes_per_hour
print(f"There are {seconds_per_hour} seconds in 1 hour")
# Out:
# There are 3600 seconds in 1 hour

# %%
seconds_per_hour = 3600
seconds_per_day = seconds_per_hour * 24
print(f"There are {seconds_per_day} seconds in a day")
# Out:
# There are 86400 seconds in a day

# %%
seconds_per_day = 86400
seconds_per_hour = 3600
fpoint = seconds_per_day / seconds_per_hour
print(fpoint)
# Out:
# 24.0

# %%
seconds_per_day = 86400
seconds_per_hour = 3600
idivision = seconds_per_day // seconds_per_hour
print(idivision)
# Out:
# 24

# %% [markdown]
# Yes the number did agree with the floating point notation from the previous question minus the .0
